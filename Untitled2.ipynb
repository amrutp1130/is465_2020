# %%
import geopandas as gpd 
shapefile = 'C:/Users/amrut/Downloads/County_Boundaries_of_NJ/County_Boundaries_of_NJ.shp'
map_file = gpd.read_file(shapefile)

map_file.head()
# Out:
#    OBJECTID      COUNTY         COUNTY_LAB   CO             GNIS_NAME    GNIS  \
# 0         1    ATLANTIC    Atlantic County  ATL    County of Atlantic  882270
# 1         2      BERGEN      Bergen County  BER      County of Bergen  882271
# 2         3  BURLINGTON  Burlington County  BUR  County of Burlington  882272
# 3         4      CAMDEN      Camden County  CAM      County of Camden  882273
# 4         5    CAPE MAY    Cape May County  CAP    County of Cape May  882274
#
#   FIPSSTCO FIPSCO          ACRES    SQ_MILES  ...  POP1980  POPDEN2010  \
# 0    34001      1  390815.404215  610.649069  ...   204615         450
# 1    34003      3  153490.275182  239.828555  ...   849843        3774
# 2    34005      5  524903.339615  820.161468  ...   362542         547
# 3    34007      7  145598.488079  227.497638  ...   471650        2258
# 4    34009      9  183126.574240  286.135272  ...    82266         340
#
#    POPDEN2000  POPDEN1990  POPDEN1980        REGION  \
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
datafile = 'C:/Users/amrut/Documents/covid-19-NJ.csv'
r_datafile = pd.read_csv(datafile)
r_datafile.head()
# Out:
#        COUNTY  Cases
# 0    Atlantic    211
# 1      Bergen  8,928
# 2  Burlington    954
# 3      Camden  1,072
# 4   Cape May     116

# %%
map_file.plot()

# %%
merged = map_file.merge(r_datafile, left_on = 'COUNTY' , right_on = 'COUNTY')
merged.head()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     343             method = get_real_method(obj, self.print_method)
#     344             if method is not None:
# --> 345                 return method()
#     346             return None
#     347         else:
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _repr_html_(self)
#     685                 show_dimensions=show_dimensions,
#     686             )
# --> 687             formatter.to_html(notebook=True)
#     688             return formatter.buf.getvalue()
#     689         else:
#
# ~\Anaconda3\lib\site-packages\pandas\io\formats\format.py in to_html(self, classes, notebook, border)
#     838
#     839         Klass = NotebookFormatter if notebook else HTMLFormatter
# ...
