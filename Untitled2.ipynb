# %%
import geopandas as gpd 
shapefile = './County_Boundaries_of_NJ/County_Boundaries_of_NJ.shp'
map_file = gpd.read_file(shapefile)

map_file.head()
# Out:
#    OBJECTID      COUNTY         COUNTY_LAB   CO             GNIS_NAME    GNIS  \
# 0         1    ATLANTIC    Atlantic County  ATL    County of Atlantic  882270
# 1         2      BERGEN      Bergen County  BER      County of Bergen  882271
# 2         3  BURLINGTON  Burlington County  BUR  County of Burlington  882272
# 3         4      CAMDEN      Camden County  CAM      County of Camden  882273
# 4         5    CAPE MAY    Cape May County  CAP    County of Cape May  882274
#
#   FIPSSTCO FIPSCO          ACRES    SQ_MILES  ...  POP1980  POPDEN2010  \
# 0    34001      1  390815.404215  610.649069  ...   204615         450
# 1    34003      3  153490.275182  239.828555  ...   849843        3774
# 2    34005      5  524903.339615  820.161468  ...   362542         547
# 3    34007      7  145598.488079  227.497638  ...   471650        2258
# 4    34009      9  183126.574240  286.135272  ...    82266         340
#
#    POPDEN2000  POPDEN1990  POPDEN1980        REGION  \
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
datafile = './covid-19-NJ.csv'
r_datafile = pd.read_csv(datafile, thousands=',')
r_datafile.head()
# Out:
#        COUNTY  Cases
# 0    Atlantic    211
# 1      Bergen   8928
# 2  Burlington    954
# 3      Camden   1072
# 4   Cape May     116

# %%
map_file.plot()

# %%
merged = map_file.merge(r_datafile, how = 'outer', left_index = True , right_index = True)
merged.head()
# Out:
#    OBJECTID    COUNTY_x         COUNTY_LAB   CO             GNIS_NAME    GNIS  \
# 0         1    ATLANTIC    Atlantic County  ATL    County of Atlantic  882270
# 1         2      BERGEN      Bergen County  BER      County of Bergen  882271
# 2         3  BURLINGTON  Burlington County  BUR  County of Burlington  882272
# 3         4      CAMDEN      Camden County  CAM      County of Camden  882273
# 4         5    CAPE MAY    Cape May County  CAP    County of Cape May  882274
#
#   FIPSSTCO FIPSCO          ACRES    SQ_MILES  ...  POPDEN2000  POPDEN1990  \
# 0    34001      1  390815.404215  610.649069  ...         414         451
# 1    34003      3  153490.275182  239.828555  ...        3686        3459
# 2    34005      5  524903.339615  820.161468  ...         516         482
# 3    34007      7  145598.488079  227.497638  ...        2237        2341
# 4    34009      9  183126.574240  286.135272  ...         358         332
#
# ...

# %%
variable = 'Cases'
vmin, vmax = 100,230
fig, ax = plt.subplots(1, figsize=(10, 6))
merged.plot(column=variable, cmap= 'Reds', linewidth=0.8, ax=ax, edgecolor='0.8')
ax.set_title('Covid-19 Cases in New Jersey', \
              fontdict={'fontsize': '25',
                        'fontweight' : '3'})

sm = plt.cm.ScalarMappable(cmap='Reds', norm=plt.Normalize(vmin=vmin, vmax=vmax))
sm._A = []
cbar = fig.colorbar(sm)
ax.axis('off')
# Out:
# (170515.9983667707, 680228.4248388322, -9284.773559535293, 963786.8361332513)
